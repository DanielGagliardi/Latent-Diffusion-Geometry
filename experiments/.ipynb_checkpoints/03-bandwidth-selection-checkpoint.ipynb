# %% [markdown]
# # Trying to find the correct bandwidth for estimating curvature when noise and reach are unknown

# %%
overview: we can estimate curvature of a manifold when we know the reach and noise level
